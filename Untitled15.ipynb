# %% [markdown]
# <a href="https://colab.research.google.com/github/Altz-L/Informatics/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
workouts = pd.read_csv('workouts (2).csv', parse_dates=['start_at'])

users = pd.read_excel('users (2).xlsx')

# %%
workouts_users =  pd.merge(workouts, users,
                     how='left',
                     left_on='client_id', right_on='user_id')

# %% [markdown]
# # 1. Задание

# %%
workouts_by_day = workouts.resample('D', on='start_at')['workout_id'].count()

# %%
plt.figure(figsize=(10, 5))
plt.title('Распределение количества тренировок по дням')
plt.xlabel('Дата')
plt.ylabel('Количество тренировок')
plt.grid()

plt.plot(workouts_by_day.iloc[:-1])
plt.show()

# %% [markdown]
# ### Коментарий
# Вижу что с начала 2020 количество тренировок росло до начала лета, потом падало до начала осени и снова начало рости, ближе к новому году темпы роста снизились и пошли на небольшой спад

# %% [markdown]
# # 2. Задание

# %%
# выбрали тренеров, которые вели тренировки до 1 ноября
trainers_select = workouts['trainer_id'].loc[workouts['start_at'] < '2020-11-01']

# множеством взяли уникальные значения
trainers_select = set(trainers_select)

# %%
# взяли тренировки только за ноябрь
november_workouts = workouts.loc[workouts['start_at'].dt.month == 11]

# берем только активных тренеров
november_workouts = november_workouts.loc[november_workouts['trainer_id'].isin(trainers_select)]

# %%
# кол-во тренировок у каждого тренера
workouts_by_trainer = november_workouts.groupby(['trainer_id','trainer_department'])['workout_id'].count()

# превращаем series в dataframe, сбрасываем индекс
workouts_by_trainer = workouts_by_trainer.reset_index()

# переименовываем столбец workout_id, ведь в нем теперь количество тренировок
workouts_by_trainer.columns = ['trainer_id','trainer_department','workouts']

workouts_by_trainer = workouts_by_trainer.dropna()

workouts_by_trainer.head()
# Out:
#    trainer_id trainer_department  workouts
# 0      1994.0          Spartacus        13
# 1      4446.0          Spartacus         9
# 2     14431.0          Spartacus        11
# 3     15062.0          Spartacus         8
# 4     15691.0          Spartacus        11

# %%
# посмотрим, какие у нас есть департаменты
departments = set(workouts_by_trainer['trainer_department'])
departments
# Out:
# {'Athletic',
#  'Consultant',
#  'Cycling',
#  'Dinamo',
#  'Sales',
#  'Spartacus',
#  'Sports Reserves'}

# %%
for dep in departments:
  plt.figure(figsize=(10, 5))
  plt.title(f'Распределение среднего месячного количества тренировок департамента {dep}')
  plt.xlabel('Количество тренировок в ноябре')
  plt.ylabel('Количество тренеров')
  plt.grid()

  plt.hist(workouts_by_trainer.loc[workouts_by_trainer['trainer_department'] == dep]['workouts'])

  plt.show()

# %% [markdown]
# ## 3. Задание

# %%
plt.figure(figsize=(10, 5))
plt.title('Распределение количества тренировок в ноябре по департаментам')
plt.grid()

sns.boxplot(x='trainer_department',
            y='workouts',
            data=workouts_by_trainer,
            color='y')
plt.ylabel('Ср. кол-во тренировок в ноябре')
plt.xlabel('Департамент')
plt.show()

# %% [markdown]
# ### Коментарий
# В Spartacus, Sports Reserves и Dinamo есть тренеров с огромной нагрузкой, часть их тренировок можно распределить между тренерами Sales и Consultant где у трненеров почти нет работы

# %% [markdown]
# # 4. Задание

# %%
# отфильтровали бесплатные тренировки и сделали копию датафрейма
cost_age_data = workouts_users[['status','cost','age']].loc[workouts_users.workout_schedule_type!='trial'].dropna().copy()

# Изменяем тип данных столбцов age и cost на int. Это нужно, чтобы на подписях к диаграммам числа были целыми
cost_age_data['age'] = cost_age_data['age'].apply(int)
cost_age_data['cost'] = cost_age_data['cost'].apply(int)

# Кодируем столбец status, присваивая 1 в случаях, если он равен failed_by_client и 0 в случае success
cost_age_data['status'] = cost_age_data.status.map({'success':0,'failed_by_client':1})

# создаём агрегированные наборы данных
cost_age_data_agg = cost_age_data.groupby(['cost','age'])['status'].mean().reset_index() #считаем долю прогулов по возрасту и цене

cost_age_data_agg
# Out:
#      cost  age    status
# 0     500    6  0.500000
# 1     500    7  0.000000
# 2     500    8  0.300000
# 3     500    9  0.235294
# 4     500   10  0.343750
# ..    ...  ...       ...
# 182  1500   47  0.000000
# 183  1500   49  0.125000
# 184  1500   50  0.500000
# 185  1500   55  0.187500
# 186  1500   68  0.000000
#
# [187 rows x 3 columns]

# %%
cost_status = cost_age_data_agg[['cost', 'status']]

# %%
plt.figure(figsize=(8, 8))

plt.xlim(400, 1_600)
plt.ylim(-0.01, 0.61)

plt.title('Зависимость количества прогулов от цены')
plt.xlabel('Цена')
plt.ylabel('Процент прогулов')

plt.grid()

plt.scatter(
    cost_status.cost,
    cost_status.status,
    alpha = 0.7,
    c = 'g'
)

plt.show()

# %% [markdown]
# ### Коментарий
# Наблюдается снижение количества прогулов при повышении цены

# %%
age_status = cost_age_data_agg[['age', 'status']]

# %%
plt.figure(figsize=(8, 8))

plt.title('Зависимость количества прогулов от возраста')
plt.xlabel('Возраст')
plt.ylabel('Процент прогулов')

plt.grid()

plt.scatter(
    age_status.age,
    age_status.status,
    alpha = 0.7,
    c = 'g'
)

plt.show()

# %% [markdown]
# ### Коментарий
# Выдно что люди в возрасте от 30 до 40 пропускают тренировки реже остальных возрастных групп, а люди в возрасте до 30 стабильно пропускают 15-30% тренировок

# %%
costs = set(cost_age_data_agg['cost'])

costs
# Out:
# {500, 750, 1000, 1500}

# %%
price_color = {500:'g',
               750:'b',
               1000:'y',
               1500:'r'}

# %%
plt.figure(figsize=(8, 8))

plt.title('Зависимость количества прогулов от возраста')
plt.xlabel('Возраст')
plt.ylabel('Процент прогулов')

plt.grid()

plt.scatter(
    cost_age_data_agg.age,
    cost_age_data_agg.status,
    alpha = 0.7,
    c = cost_age_data_agg['cost'].map(price_color)
)

plt.show()

# %% [markdown]
# ### Коментарий
# Тренировки за 500 пропускают кому как удобно, кареляции нет
#
# Тренировки за 750 люди возрастной группы до 32 лет пропускают стабильно около 23-30% занятий
#
# Тренировки за 1000 люди возрастной группы до 32 лет пропускают чуть реже чем за 750, но количество пропусков уменшается с приближением возраста к 32 годам, после 32 количество пропусков от почти нулевого растет в геометрической прогрессии
#
# Тренировки за 1500 пропускают хаотично кроме людей в возрасте от 32 до 48, они не пропускают тренировки вообще

# %% [markdown]
# # 5. Задание

# %%
def calculate_age_bins(age):
    if age <= 20:
        return '0-20'
    if age <= 25:
        return '21-25'
    if age <= 30:
        return '26-30'
    if age <= 35:
        return '31-35'
    if age <= 40:
        return '36-40'
    if age <= 45:
        return '41-45'
    if age <= 50:
        return '46-50'
    return '50+'

# %%
# кладем в новый столбец возрастную группу
cost_age_data['age_bin'] = cost_age_data.age.apply(calculate_age_bins)

# создаём агрегированный набор данных
cost_age_data_agg = cost_age_data.groupby(['cost','age_bin'])['status'].mean().reset_index()
cost_age_data_agg
# Out:
#     cost age_bin    status
# 0    500    0-20  0.297459
# 1    500   21-25  0.292070
# 2    500   26-30  0.250000
# 3    500   31-35  0.178694
# 4    500   36-40  0.186275
# 5    500   41-45  0.195652
# 6    500   46-50  0.250000
# 7    500     50+  0.307692
# 8    750    0-20  0.247322
# 9    750   21-25  0.251415
# 10   750   26-30  0.251687
# 11   750   31-35  0.131234
# 12   750   36-40  0.096126
# 13   750   41-45  0.110207
# 14   750   46-50  0.202929
# 15   750     50+  0.302970
# 16  1000    0-20  0.208298
# 17  1000   21-25  0.191337
# 18  1000   26-30  0.193400
# 19  1000   31-35  0.071148
# 20  1000   36-40  0.037652
# 21  1000   41-45  0.073286
# 22  1000   46-50  0.183246
# 23  1000     50+  0.239130
# 24  1500    0-20  0.129534
# 25  1500   21-25  0.179825
# 26  1500   26-30  0.126866
# 27  1500   31-35  0.118774
# 28  1500   36-40  0.000000
# 29  1500   41-45  0.000000
# 30  1500   46-50  0.097561
# 31  1500     50+  0.176471

# %%
table =  cost_age_data_agg.pivot(index="age_bin",
                                 columns="cost",
                                 values="status")

# %%
plt.figure(figsize=(20,8))
sns.heatmap(table,
            annot=True,
            cmap="YlGnBu",
            fmt='g')
plt.title("Процент прогулов по возрастным группам и цене")
plt.ylabel("Возрастная группа")
plt.xlabel("Цена")
plt.show()

# %% [markdown]
# ### Коментарий
# От 36 до 45 реже всеч остальных груп пропускают тренировки и чем больше они платят, тем чаще ходят
#
# До 30 и за 50 больше четверти тренировок стоимостью 500 и 750
